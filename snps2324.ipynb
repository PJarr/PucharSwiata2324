# %%
import pandas as pd
import numpy as np
import requests
from sqlalchemy import create_engine, text

# %%
wc_results = {
    "2023-11-25":{
        "Miasto": "Ruka",
        "url": "https://www.skijumping.pl/wyniki/zawody/5068"
    },
    "2023-11-26":{
        "Miasto": "Ruka",
        "url": "https://www.skijumping.pl/wyniki/zawody/5069"
    },
    "2023-12-02":{
        "Miasto": "Lillehammer",
        "url": "https://www.skijumping.pl/wyniki/zawody/5070"
    },
    "2023-12-03":{
        "Miasto": "Lillehammer",
        "url": "https://www.skijumping.pl/wyniki/zawody/5071"
    },
    "2023-12-09":{
        "Miasto": "Klingenthal",
        "url": "https://www.skijumping.pl/wyniki/zawody/5072"
    },
    "2023-12-10":{
        "Miasto": "Klingenthal",
        "url": "https://www.skijumping.pl/wyniki/zawody/5073"
    },
    "2023-12-16":{
        "Miasto": "Engelberg",
        "url": "https://www.skijumping.pl/wyniki/zawody/5074"
    },
    "2023-12-17":{
        "Miasto": "Engelberg",
        "url": "https://www.skijumping.pl/wyniki/zawody/5075"
    },
    "2023-12-29":{
        "Miasto": "Oberstdorf",
        "url": "https://www.skijumping.pl/wyniki/zawody/5076"
    },
    "2024-01-01":{
        "Miasto": "Garmisch-Partenkirchen",
        "url": "https://www.skijumping.pl/wyniki/zawody/5077"
    },
    "2024-01-03":{
        "Miasto": "Innsbruck",
        "url": "https://www.skijumping.pl/wyniki/zawody/5078"
    },
    "2024-01-06":{
        "Miasto": "Bischofshofen",
        "url": "https://www.skijumping.pl/wyniki/zawody/5079"
    },
    "2024-01-14":{
        "Miasto": "Wisła",
        "url": "https://www.skijumping.pl/wyniki/zawody/5081"
    },
    "2024-01-21":{
        "Miasto": "Zakopane",
        "url": "https://www.skijumping.pl/wyniki/zawody/5084"
    },
    "2024-02-03":{
        "Miasto": "Willingen",
        "url": "https://www.skijumping.pl/wyniki/zawody/5088"
    },
    "2024-02-04":{
        "Miasto": "Willingen",
        "url": "https://www.skijumping.pl/wyniki/zawody/5089"
    },
    "2024-02-10":{
        "Miasto": "Lake Placid",
        "url": "https://www.skijumping.pl/wyniki/zawody/5090"
    },
    "2024-02-11":{
        "Miasto": "Lake Placid",
        "url": "https://www.skijumping.pl/wyniki/zawody/5092"
    },
    "2024-02-17":{
        "Miasto": "Sapporo",
        "url": "https://www.skijumping.pl/wyniki/zawody/5093"
    },
    "2024-02-18":{
        "Miasto": "Sapporo",
        "url": "https://www.skijumping.pl/wyniki/zawody/5094"
    },
    "2024-02-24":{
        "Miasto": "Oberstdorf",
        "url": "https://www.skijumping.pl/wyniki/zawody/5096"
    },
    "2024-02-25":{
        "Miasto": "Oberstdorf",
        "url": "https://www.skijumping.pl/wyniki/zawody/5097"
    },
    "2024-03-01":{
        "Miasto": "Lahti",
        "url": "https://www.skijumping.pl/wyniki/zawody/5268"
    },
    "2024-03-03":{
        "Miasto": "Lahti",
        "url": "https://www.skijumping.pl/wyniki/zawody/5099"
    },
    "2024-03-09":{
        "Miasto": "Oslo",
        "url": "https://www.skijumping.pl/wyniki/zawody/5100"
    },
    "2024-03-10":{
        "Miasto": "Oslo",
        "url": "https://www.skijumping.pl/wyniki/zawody/5101"
    },
    "2024-03-12":{
        "Miasto": "Trondheim",
        "url": "https://www.skijumping.pl/wyniki/zawody/5102"
    },
    "2024-03-13":{
        "Miasto": "Trondheim",
        "url": "https://www.skijumping.pl/wyniki/zawody/5103"
    },
    "2024-03-17_1":{
        "Miasto": "Vikersund_1",
        "url": "https://www.skijumping.pl/wyniki/zawody/5104"
    },
    "2024-03-17_2":{
        "Miasto": "Vikersund_2",
        "url": "https://www.skijumping.pl/wyniki/zawody/5105"
    },
    "2024-03-22":{
        "Miasto": "Planica",
        "url": "https://www.skijumping.pl/wyniki/zawody/5106"
    },
    "2024-03-24":{
        "Miasto": "Planica",
        "url": "https://www.skijumping.pl/wyniki/zawody/5108"
    }
}

# %%
wc_standings = {
    "2023-11-25":{
        "Miasto": "Ruka",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12161"
    },
    "2023-11-26":{
        "Miasto": "Ruka",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12163"
    },
    "2023-12-02":{
        "Miasto": "Lillehammer",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12172"
    },
    "2023-12-03":{
        "Miasto": "Lillehammer",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12178"
    },
    "2023-12-09":{
        "Miasto": "Klingenthal",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12192"
    },
    "2023-12-10":{
        "Miasto": "Klingenthal",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12200"
    },
    "2023-12-16":{
        "Miasto": "Engelberg",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12238"
    },
    "2023-12-17":{
        "Miasto": "Engelberg",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12242"
    },
    "2023-12-29":{
        "Miasto": "Oberstdorf",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12258"
    },
    "2024-01-01":{
        "Miasto": "Garmisch-Partenkirchen",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12269"
    },
    "2024-01-03":{
        "Miasto": "Innsbruck",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12279"
    },
    "2024-01-06":{
        "Miasto": "Bischofshofen",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12292"
    },
    "2024-01-14":{
        "Miasto": "Wisła",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12336"
    },
    "2024-01-21":{
        "Miasto": "Zakopane",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12379"
    },
    "2024-02-03":{
        "Miasto": "Willingen",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12409"
    },
    "2024-02-04":{
        "Miasto": "Willingen",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12417"
    },
    "2024-02-10":{
        "Miasto": "Lake Placid",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12444"
    },
    "2024-02-11":{
        "Miasto": "Lake Placid",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12447"
    },
    "2024-02-17":{
        "Miasto": "Sapporo",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12460"
    },
    "2024-02-18":{
        "Miasto": "Sapporo",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12462"
    },
    "2024-02-24":{
        "Miasto": "Oberstdorf",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12490"
    },
    "2024-02-25":{
        "Miasto": "Oberstdorf",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12497"
    },
    "2024-03-01":{
        "Miasto": "Lahti",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12505"
    },
    "2024-03-03":{
        "Miasto": "Lahti",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12519"
    },
    "2024-03-09":{
        "Miasto": "Oslo",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12535"
    },
    "2024-03-10":{
        "Miasto": "Oslo",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12553"
    },
    "2024-03-12":{
        "Miasto": "Trondheim",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12559"
    },
    "2024-03-13":{
        "Miasto": "Trondheim",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12565"
    },
    "2024-03-17_1":{
        "Miasto": "Vikersund_1",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12583"
    },
    "2024-03-17_2":{
        "Miasto": "Vikersund_2",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12584"
    },
    "2024-03-22":{
        "Miasto": "Planica",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12594"
    },
    "2024-03-24":{
        "Miasto": "Planica",
        "url": "https://www.skokinarciarskie.pl/index.php?a=cykle&b=klas_k&cykl=ps&sezon=2023/2024&id=12598"
    }
}

# %%
# wc calendar data
wc_url = "https://skokipolska.pl/puchar-swiata-2023-2024/"
df_wc_calendar = pd.read_html(wc_url, header=0)[2]

# %%
df_wc_calendar
# Out:
#                                                  data  \
# 0                                    3. period sezonu
# 1                                 25.11.2023 (sobota)
# 2                              26.11.2023 (niedziela)
# 3                                 02.12.2023 (sobota)
# 4                              03.12.2023 (niedziela)
# 5                                 09.12.2023 (sobota)
# 6                              10.12.2023 (niedziela)
# 7                                 16.12.2023 (sobota)
# 8                              17.12.2023 (niedziela)
# 9                                    4. period sezonu
# 10                                29.12.2023 (piątek)
# 11                          01.01.2024 (poniedziałek)
# 12                                 03.01.2024 (środa)
# 13                                06.01.2024 (sobota)
# 14                                   5. period sezonu
# 15                                13.01.2024 (sobota)
# ...

# %%
df_wc_calendar = df_wc_calendar.loc[~(df_wc_calendar["data"].str.contains("period") | df_wc_calendar["miejsce (kraj)"].str.lower().str.contains('bad mitterndorf'))]

# %%
df_wc_calendar
# Out:
#                                              data  \
# 1                             25.11.2023 (sobota)
# 2                          26.11.2023 (niedziela)
# 3                             02.12.2023 (sobota)
# 4                          03.12.2023 (niedziela)
# 5                             09.12.2023 (sobota)
# 6                          10.12.2023 (niedziela)
# 7                             16.12.2023 (sobota)
# 8                          17.12.2023 (niedziela)
# 10                            29.12.2023 (piątek)
# 11                      01.01.2024 (poniedziałek)
# 12                             03.01.2024 (środa)
# 13                            06.01.2024 (sobota)
# 15                            13.01.2024 (sobota)
# 16                         14.01.2024 (niedziela)
# 17                             17.01.2024 (środa)
# 18                            20.01.2024 (sobota)
# 19                         21.01.2024 (niedziela)
# 25                            03.02.2024 (sobota)
# ...

# %%
df_wc_calendar.loc[:,'WC_Date'] = df_wc_calendar['data'].str.split(" ", expand=True)[0]
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\2217670209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar.loc[:,'WC_Date'] = df_wc_calendar['data'].str.split(" ", expand=True)[0]

# %%
df_wc_calendar.drop(columns="data", inplace=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3623115199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar.drop(columns="data", inplace=True)

# %%
df_wc_calendar.head(5)
# Out:
#            miejsce (kraj)        skocznia                 zawody  \
# 1        Ruka (Finlandia)  HS-142 (K-120)  indywidualne wyniki >
# 2        Ruka (Finlandia)  HS-142 (K-120)  indywidualne wyniki >
# 3  Lillehammer (Norwegia)    HS-98 (K-90)  indywidualne wyniki >
# 4  Lillehammer (Norwegia)  HS-140 (K-123)  indywidualne wyniki >
# 5    Klingenthal (Niemcy)  HS-140 (K-125)  indywidualne wyniki >
#
#           zwycięzca     WC_Date
# 1  Stefan Kraft AUT  25.11.2023
# 2  Stefan Kraft AUT  26.11.2023
# 3  Stefan Kraft AUT  02.12.2023
# 4  Stefan Kraft AUT  03.12.2023
# 5   Karl Geiger GER  09.12.2023

# %%
df_wc_calendar[["Miasto","Kraj"]] = df_wc_calendar["miejsce (kraj)"].str.split(" \(",expand=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3929719140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar[["Miasto","Kraj"]] = df_wc_calendar["miejsce (kraj)"].str.split(" \(",expand=True)
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3929719140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar[["Miasto","Kraj"]] = df_wc_calendar["miejsce (kraj)"].str.split(" \(",expand=True)

# %%
df_wc_calendar.drop(columns="miejsce (kraj)",inplace=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\2928662777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar.drop(columns="miejsce (kraj)",inplace=True)

# %%
df_wc_calendar["Kraj"] = df_wc_calendar["Kraj"].str.replace(")","")
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3039153549.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_wc_calendar["Kraj"] = df_wc_calendar["Kraj"].str.replace(")","")
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3039153549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar["Kraj"] = df_wc_calendar["Kraj"].str.replace(")","")

# %%
df_wc_calendar.reset_index(inplace=True,drop=True)

# %%
df_wc_calendar
# Out:
#           skocznia                      zawody                 zwycięzca  \
# 0   HS-142 (K-120)       indywidualne wyniki >          Stefan Kraft AUT
# 1   HS-142 (K-120)       indywidualne wyniki >          Stefan Kraft AUT
# 2     HS-98 (K-90)       indywidualne wyniki >          Stefan Kraft AUT
# 3   HS-140 (K-123)       indywidualne wyniki >          Stefan Kraft AUT
# 4   HS-140 (K-125)       indywidualne wyniki >           Karl Geiger GER
# 5   HS-140 (K-125)       indywidualne wyniki >           Karl Geiger GER
# 6   HS-140 (K-125)      indywidualne program >          Pius Paschke GER
# 7   HS-140 (K-125)      indywidualne program >          Stefan Kraft AUT
# 8   HS-137 (K-120)         ind. TCS * wyniki >     Andreas Wellinger GER
# 9   HS-142 (K-125)           ind. TCS wyniki >          Anze Lanisek SLO
# 10  HS-128 (K-120)           ind. TCS wyniki >             Jan Hoerl AUT
# 11  HS-142 (K-125)           ind. TCS wyniki >          Stefan Kraft AUT
# ...

# %%
df_wc_calendar.iloc[30,5] = "Finlandia"

# %%
df_wc_calendar[["HS_Point","K_Point"]] = df_wc_calendar["skocznia"].str.split(" \(",expand=True)
df_wc_calendar.drop(columns="skocznia",inplace=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3315565870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar[["HS_Point","K_Point"]] = df_wc_calendar["skocznia"].str.split(" \(",expand=True)
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\3315565870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar[["HS_Point","K_Point"]] = df_wc_calendar["skocznia"].str.split(" \(",expand=True)
# ...

# %%
df_wc_calendar["K_Point"] = df_wc_calendar["K_Point"].str.replace(r'\D','',regex=True)
df_wc_calendar["HS_Point"] = df_wc_calendar["HS_Point"].str.replace(r'\D','',regex=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\700901479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar["K_Point"] = df_wc_calendar["K_Point"].str.replace(r'\D','',regex=True)
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\700901479.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar["HS_Point"] = df_wc_calendar["HS_Point"].str.replace(r'\D','',regex=True)

# %%
df_wc_calendar[["Zwyciezca","Narodowosc"]] = df_wc_calendar["zwycięzca"].str.rsplit(" ",n=1,expand=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\1410355408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar[["Zwyciezca","Narodowosc"]] = df_wc_calendar["zwycięzca"].str.rsplit(" ",n=1,expand=True)
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\1410355408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar[["Zwyciezca","Narodowosc"]] = df_wc_calendar["zwycięzca"].str.rsplit(" ",n=1,expand=True)

# %%
df_wc_calendar.drop(columns="zwycięzca", inplace=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\60826825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar.drop(columns="zwycięzca", inplace=True)

# %%
df_wc_calendar["Zawody"] = df_wc_calendar["zawody"].str.split(expand=True)[0]
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\844657414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar["Zawody"] = df_wc_calendar["zawody"].str.split(expand=True)[0]

# %%
df_wc_calendar.drop(columns="zawody", inplace=True)
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\1225976962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar.drop(columns="zawody", inplace=True)

# %%
mapper = {"ind.":"indywidualne","druż.":"drużynowe"}

# %%
df_wc_calendar["Zawody"] = df_wc_calendar["Zawody"].map(mapper).fillna(df_wc_calendar["Zawody"])
# Out:
# C:\Users\Paweł\AppData\Local\Temp\ipykernel_29604\1470247869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wc_calendar["Zawody"] = df_wc_calendar["Zawody"].map(mapper).fillna(df_wc_calendar["Zawody"])

# %%
df_wc_calendar.iloc[34,1]='Vikersund_1'
df_wc_calendar.iloc[35,1]='Vikersund_2'

# %%
df_wc_calendar
# Out:
#        WC_Date                  Miasto  \
# 0   25.11.2023                    Ruka
# 1   26.11.2023                    Ruka
# 2   02.12.2023             Lillehammer
# 3   03.12.2023             Lillehammer
# 4   09.12.2023             Klingenthal
# 5   10.12.2023             Klingenthal
# 6   16.12.2023               Engelberg
# 7   17.12.2023               Engelberg
# 8   29.12.2023              Oberstdorf
# 9   01.01.2024  Garmisch-Partenkirchen
# 10  03.01.2024               Innsbruck
# 11  06.01.2024           Bischofshofen
# 12  13.01.2024                   Wisła
# 13  14.01.2024                   Wisła
# 14  17.01.2024                 Szczyrk
# 15  20.01.2024                Zakopane
# 16  21.01.2024                Zakopane
# 17  03.02.2024               Willingen
# 18  04.02.2024               Willingen
# 19  10.02.2024             Lake Placid
# 20  10.02.2024             Lake Placid
# 21  11.02.2024             Lake Placid
# 22  17.02.2024                 Sapporo
# ...

# %%
df_wc_calendar = df_wc_calendar.loc[(df_wc_calendar["Zawody"] =='indywidualne') & (df_wc_calendar["Miasto"] != 'Szczyrk')].reset_index(drop=True)

# %%
df_wc_calendar["WC_Date"] = pd.to_datetime(df_wc_calendar["WC_Date"],format="%d.%m.%Y").dt.strftime("%Y-%m-%d")

# %%
df_wc_calendar = df_wc_calendar.loc[:,["WC_Date","Miasto","K_Point","HS_Point","Zawody","Zwyciezca","Narodowosc"]]

# %%
df_wc_calendar
# Out:
#        WC_Date                  Miasto K_Point HS_Point        Zawody  \
# 0   2023-11-25                    Ruka     120      142  indywidualne
# 1   2023-11-26                    Ruka     120      142  indywidualne
# 2   2023-12-02             Lillehammer      90       98  indywidualne
# 3   2023-12-03             Lillehammer     123      140  indywidualne
# 4   2023-12-09             Klingenthal     125      140  indywidualne
# 5   2023-12-10             Klingenthal     125      140  indywidualne
# 6   2023-12-16               Engelberg     125      140  indywidualne
# 7   2023-12-17               Engelberg     125      140  indywidualne
# 8   2023-12-29              Oberstdorf     120      137  indywidualne
# 9   2024-01-01  Garmisch-Partenkirchen     125      142  indywidualne
# 10  2024-01-03               Innsbruck     120      128  indywidualne
# 11  2024-01-06           Bischofshofen     125      142  indywidualne
# ...

# %%
df_wc_calendar = df_wc_calendar.astype({"K_Point":"int","HS_Point":"int"})

# %%
df_wc_calendar = df_wc_calendar.loc[:,["WC_Date","Miasto","K_Point","HS_Point","Zawody"]]

# %%
df_wc_calendar
# Out:
#        WC_Date                  Miasto  K_Point  HS_Point        Zawody
# 0   2023-11-25                    Ruka      120       142  indywidualne
# 1   2023-11-26                    Ruka      120       142  indywidualne
# 2   2023-12-02             Lillehammer       90        98  indywidualne
# 3   2023-12-03             Lillehammer      123       140  indywidualne
# 4   2023-12-09             Klingenthal      125       140  indywidualne
# 5   2023-12-10             Klingenthal      125       140  indywidualne
# 6   2023-12-16               Engelberg      125       140  indywidualne
# 7   2023-12-17               Engelberg      125       140  indywidualne
# 8   2023-12-29              Oberstdorf      120       137  indywidualne
# 9   2024-01-01  Garmisch-Partenkirchen      125       142  indywidualne
# 10  2024-01-03               Innsbruck      120       128  indywidualne
# 11  2024-01-06           Bischofshofen      125       142  indywidualne
# ...

# %%
# Database connection parameters
server_name = 'DESKTOP-F00PL4B\SQLEXPRESS01'
database_name = 'PortfolioProject'
table_name = 'WC_Calendar2324'

# SQLAlchemy engine creation with Windows Authentication
engine = create_engine(f"mssql+pyodbc://@{server_name}/{database_name}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# Truncate the table before inserting new data
with engine.connect() as connection:
    with connection.begin() as transaction:
        connection.execute(text(f"DELETE FROM {table_name}"))
        connection.execute(text(f"DBCC CHECKIDENT ('{table_name}', RESEED, 0)"))
        transaction.commit()

# Insert DataFrame into the existing table with column mapping
df_wc_calendar.to_sql(name=table_name, con=engine, if_exists='append', index=False)

# Close the database connection
engine.dispose()

# %%
#world cup results
frames = []
for date, value in wc_results.items():
    url = value["url"]
    miasto = value["Miasto"]
    frame = pd.read_html(url, header=0)[0]

    frame.insert(0,"WC_Date",date)
    frame.insert(1,"Miasto",miasto)
  
    
    frames.append(frame)

df_wc_results = pd.concat(frames, axis=0)

# %%
df_wc_results
# Out:
#        WC_Date   Miasto  Lp.           Zawodnik  Kraj  Odl.1  Odl.2 Suma pkt.  \
# 0   2023-11-25     Ruka    1       KRAFT Stefan   NaN  144.0    143     326.2
# 1   2023-11-25     Ruka    2       PASCHKE Pius   NaN  142.0  142.5     315.6
# 2   2023-11-25     Ruka    3      LEYHE Stephan   NaN  137.0  143.5     313.2
# 3   2023-11-25     Ruka    4  WELLINGER Andreas   NaN  142.0    136     311.5
# 4   2023-11-25     Ruka    5  TSCHOFENIG Daniel   NaN  136.0  140.5     310.3
# ..         ...      ...  ...                ...   ...    ...    ...       ...
# 25  2024-03-24  Planica   26      KYTOSAHO Niko   NaN    213  199.5     328.9
# 26  2024-03-24  Planica   27      LEYHE Stephan   NaN    199  200.5     313.8
# 27  2024-03-24  Planica   28        AALTO Antti   NaN    193  186.5     297.2
# 28  2024-03-24  Planica   29      KUBACKI Dawid   NaN    194  187.5     294.3
# 29  2024-03-24  Planica  DNS          HOERL Jan   NaN      -      -         -
#
#    Odl.3
# 0    NaN
# 1    NaN
# ...

# %%
df_wc_results["Lp."] = pd.to_numeric(df_wc_results["Lp."], errors="coerce")
df_wc_results["Odl.1"] = pd.to_numeric(df_wc_results["Odl.1"],errors="coerce")
df_wc_results["Odl.2"] = pd.to_numeric(df_wc_results["Odl.2"],errors="coerce")
df_wc_results["Odl.3"] = pd.to_numeric(df_wc_results["Odl.3"],errors="coerce")
df_wc_results["Suma pkt."] = pd.to_numeric(df_wc_results["Suma pkt."], errors="coerce")

# %%
df_wc_results.reset_index(drop=True, inplace=True)

# %%
df_wc_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1522 entries, 0 to 1521
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WC_Date    1522 non-null   object
#  1   Miasto     1522 non-null   object
#  2   Lp.        1494 non-null   float64
#  3   Zawodnik   1522 non-null   object
#  4   Kraj       0 non-null      float64
#  5   Odl.1      1516 non-null   float64
#  6   Odl.2      914 non-null    float64
#  7   Suma pkt.  1516 non-null   float64
#  8   Odl.3      10 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 107.1+ KB

# %%
df_wc_results.rename(columns={"Lp.":"Miejsce","Odl.1":"Skok_1","Odl.2":"Skok_2","Odl.3":"Skok_3","Suma pkt.":"Nota"},inplace=True)

# %%
df_wc_results = df_wc_results.loc[:,["WC_Date","Miasto","Miejsce","Zawodnik","Kraj","Skok_1","Skok_2","Skok_3","Nota"]]

# %%
df_wc_results["Miasto"] = df_wc_results["Miasto"].str.replace("Wisla","Wisła")

# %%
df_wc_results['WC_Date'] = df_wc_results['WC_Date'].apply(lambda x: x[:10])

# %%
df_wc_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1522 entries, 0 to 1521
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   WC_Date   1522 non-null   object
#  1   Miasto    1522 non-null   object
#  2   Miejsce   1494 non-null   float64
#  3   Zawodnik  1522 non-null   object
#  4   Kraj      0 non-null      float64
#  5   Skok_1    1516 non-null   float64
#  6   Skok_2    914 non-null    float64
#  7   Skok_3    10 non-null     float64
#  8   Nota      1516 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 107.1+ KB

# %%
df_wc_standings = pd.read_csv("I:/Projects/Skoki Narciarskie listopad_2024/individual_wc_standings.csv", usecols=["Rank","Athlete","Country","Points","Gap","Appearances"],delimiter=";")

# %%
df_wc_standings
# Out:
#     Rank              Athlete   Country  Points   Gap  Appearances
# 0      1         KRAFT Stefan   Austria    2149     0           32
# 1      2      KOBAYASHI Ryoyu   Japonia    1673  -476           32
# 2      3    WELLINGER Andreas    Niemcy    1488  -661           32
# 3      4            HOERL Jan   Austria    1140 -1009           29
# 4      5          PREVC Peter  Słowenia    1071 -1078           30
# ..   ...                  ...       ...     ...   ...          ...
# 62    63        URLAUB Andrew       USA       4 -2145           12
# 63    64    CAMPREGHER Andrea    Włochy       3 -2146           15
# 64    64  IPCIOGLU Fatih Arda    Turcja       3 -2146            9
# 65    64         SATO Keiichi   Japonia       3 -2146            6
# 66    67        TAKEUCHI Taku   Japonia       2 -2147           10
#
# [67 rows x 6 columns]

# %%
polish_countires = df_wc_standings["Country"].unique()

# %%
english_countires = np.array(['Austria', 'Japan', 'Germany', 'Slovenia', 'Norway',
    'Switzerland', 'Poland', 'Italy', 'Finland', 'Czechia',
    'United States', 'Bulgaria', 'Estonia', 'Ukraine', 'France', 'Turkey'])

# %%
polish_to_eng = dict(zip(polish_countires,english_countires))

# %%
polish_to_eng
# Out:
# {'Austria': 'Austria',
#  'Japonia': 'Japan',
#  'Niemcy': 'Germany',
#  'Słowenia': 'Slovenia',
#  'Norwegia': 'Norway',
#  'Szwajcaria': 'Switzerland',
#  'Polska': 'Poland',
#  'Włochy': 'Italy',
#  'Finlandia': 'Finland',
#  'Czechy': 'Czechia',
#  'USA': 'United States',
#  'Bułgaria': 'Bulgaria',
#  'Estonia': 'Estonia',
#  'Ukraina': 'Ukraine',
#  'Francja': 'France',
#  'Turcja': 'Turkey'}

# %%
import requests

response = requests.get('https://restcountries.com/v3.1/all')
countries = response.json()

# Create English name to ISO alpha-3 code dictionary
country_abbrev = {country['name']['common']: country['cca3'] for country in countries}

# Proceed with the Polish to English mapping as above

# %%
country_abbrev
# Out:
# {'South Georgia': 'SGS',
#  'Grenada': 'GRD',
#  'Switzerland': 'CHE',
#  'Sierra Leone': 'SLE',
#  'Hungary': 'HUN',
#  'Taiwan': 'TWN',
#  'Wallis and Futuna': 'WLF',
#  'Barbados': 'BRB',
#  'Pitcairn Islands': 'PCN',
#  'Ivory Coast': 'CIV',
#  'Tunisia': 'TUN',
#  'Italy': 'ITA',
#  'Benin': 'BEN',
#  'Indonesia': 'IDN',
#  'Cape Verde': 'CPV',
#  'Saint Kitts and Nevis': 'KNA',
#  'Laos': 'LAO',
#  'Caribbean Netherlands': 'BES',
#  'Uganda': 'UGA',
#  'Andorra': 'AND',
#  'Burundi': 'BDI',
#  'South Africa': 'ZAF',
#  'France': 'FRA',
#  'Libya': 'LBY',
#  'Mexico': 'MEX',
#  'Gabon': 'GAB',
#  'Northern Mariana Islands': 'MNP',
#  'North Macedonia': 'MKD',
#  'China': 'CHN',
#  'Yemen': 'YEM',
#  'Saint Barthélemy': 'BLM',
#  'Guernsey': 'GGY',
#  'Solomon Islands': 'SLB',
#  'Svalbard and Jan Mayen': 'SJM',
#  'Faroe Islands': 'FRO',
#  'Uzbekistan': 'UZB',
#  'Egypt': 'EGY',
#  'Senegal': 'SEN',
#  'Sri Lanka': 'LKA',
#  'Palestine': 'PSE',
#  'Bangladesh': 'BGD',
# ...

# %%
df_wc_standings["Country_abbrev"] = df_wc_standings["Country"].map(polish_to_eng).map(country_abbrev)

# %%
df_wc_standings = df_wc_standings.loc[:,["Rank","Athlete","Country_abbrev","Points","Gap","Appearances"]]

# %%
df_wc_standings = df_wc_standings.astype({"Rank":"int","Points":"int","Gap":"int","Appearances":"int"})

# %%
df_wc_standings
# Out:
#     Rank              Athlete Country_abbrev  Points   Gap  Appearances
# 0      1         KRAFT Stefan            AUT    2149     0           32
# 1      2      KOBAYASHI Ryoyu            JPN    1673  -476           32
# 2      3    WELLINGER Andreas            DEU    1488  -661           32
# 3      4            HOERL Jan            AUT    1140 -1009           29
# 4      5          PREVC Peter            SVN    1071 -1078           30
# ..   ...                  ...            ...     ...   ...          ...
# 62    63        URLAUB Andrew            USA       4 -2145           12
# 63    64    CAMPREGHER Andrea            ITA       3 -2146           15
# 64    64  IPCIOGLU Fatih Arda            TUR       3 -2146            9
# 65    64         SATO Keiichi            JPN       3 -2146            6
# 66    67        TAKEUCHI Taku            JPN       2 -2147           10
#
# [67 rows x 6 columns]

# %%
df_wc_standings["Rank_Basket"] = np.arange(len(df_wc_standings))//10 + 1

# %%
df_wc_standings
# Out:
#     Rank              Athlete Country_abbrev  Points   Gap  Appearances  \
# 0      1         KRAFT Stefan            AUT    2149     0           32
# 1      2      KOBAYASHI Ryoyu            JPN    1673  -476           32
# 2      3    WELLINGER Andreas            DEU    1488  -661           32
# 3      4            HOERL Jan            AUT    1140 -1009           29
# 4      5          PREVC Peter            SVN    1071 -1078           30
# ..   ...                  ...            ...     ...   ...          ...
# 62    63        URLAUB Andrew            USA       4 -2145           12
# 63    64    CAMPREGHER Andrea            ITA       3 -2146           15
# 64    64  IPCIOGLU Fatih Arda            TUR       3 -2146            9
# 65    64         SATO Keiichi            JPN       3 -2146            6
# 66    67        TAKEUCHI Taku            JPN       2 -2147           10
#
#     Rank_Basket
# 0             1
# 1             1
# 2             1
# 3             1
# ...

# %%
df_wc_standings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            67 non-null     int32
#  1   Athlete         67 non-null     object
#  2   Country_abbrev  67 non-null     object
#  3   Points          67 non-null     int32
#  4   Gap             67 non-null     int32
#  5   Appearances     67 non-null     int32
#  6   Rank_Basket     67 non-null     int32
# dtypes: int32(5), object(2)
# memory usage: 2.5+ KB

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Database connection parameters
server_name = 'DESKTOP-F00PL4B\\SQLEXPRESS01'  # Double backslash to escape
database_name = 'PortfolioProject'
table_name = 'WC_Standings2324'

# SQLAlchemy engine creation with Windows Authentication
engine = create_engine(f"mssql+pyodbc://@{server_name}/{database_name}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# Step 4: Truncate the results table before inserting new data
with engine.connect() as connection:
    with connection.begin() as transaction:
        connection.execute(text(f"DELETE FROM {table_name}"))
        transaction.commit()

# Insert DataFrame into the existing table with column mapping
df_wc_standings.to_sql(name=table_name, con=engine, if_exists='append', index=False)

# Close the database connection
engine.dispose()

# %%
#world cup standings cumulative
frames  = []
for wc_date, value in wc_standings.items():
    miasto = value["Miasto"]
    url = value["url"]

    frame = pd.read_html(url, header=1)[0]
    frame = frame.loc[:,["Unnamed: 0","zawodnik", "kraj", "punkty", "strata"]]
    frame.insert(0,"WC_Date",wc_date)
    frame.insert(1,"Miasto",miasto)

    frames.append(frame)

df_wc_results_cum = pd.concat(frames,axis=0)

# %%
df_wc_results_cum.head(5)
# Out:
#       WC_Date Miasto  Unnamed: 0           zawodnik  kraj  punkty  strata
# 0  2023-11-25   Ruka         1.0       Stefan Kraft   NaN     100     NaN
# 1  2023-11-25   Ruka         2.0       Pius Paschke   NaN      80   -20.0
# 2  2023-11-25   Ruka         3.0      Stephan Leyhe   NaN      60   -40.0
# 3  2023-11-25   Ruka         4.0  Andreas Wellinger   NaN      50   -50.0
# 4  2023-11-25   Ruka         5.0  Daniel Tschofenig   NaN      45   -55.0

# %%
df_wc_results_cum.rename(columns={"Unnamed: 0":"Miejsce","zawodnik":"Zawodnik","kraj":"Kraj","punkty":"Punkty","strata":"Strata"}, inplace=True)

# %%
df_wc_results_cum.isna().sum()
# Out:
# WC_Date        0
# Miasto         0
# Miejsce      213
# Zawodnik       0
# Kraj        1820
# Punkty         0
# Strata        32
# dtype: int64

# %%
df_wc_results_cum["Miejsce"] = df_wc_results_cum["Miejsce"].fillna(method="ffill")

# %%
df_wc_results_cum.reset_index(drop=True,inplace=True)

# %%
df_wc_results_cum["Strata"].fillna(0,inplace=True)

# %%
name_split = df_wc_results_cum["Zawodnik"].str.rsplit(" ", n=1, expand=True)
df_wc_results_cum["Zawodnik"] = name_split[1].str.upper() + " " + name_split[0]

# %%
df_wc_results_cum.columns
# Out:
# Index(['WC_Date', 'Miasto', 'Miejsce', 'Zawodnik', 'Kraj', 'Punkty', 'Strata'], dtype='object')

# %%
df_wc_results_cum['WC_Date'] = df_wc_results_cum['WC_Date'].str.slice(0,10)

# %%
df_wc_results_cum = df_wc_results_cum.merge(df_wc_standings[["Athlete","Country_abbrev"]],how="left",left_on="Zawodnik", right_on="Athlete")

# %%
df_wc_results_cum = df_wc_results_cum.loc[:,["WC_Date","Miasto","Miejsce","Zawodnik","Country_abbrev","Punkty","Strata"]]

# %%
df_wc_results_cum = df_wc_results_cum.astype({"Miejsce":"int","Punkty":"int","Strata":"int"})

# %%
df_wc_results_cum.head()
# Out:
#       WC_Date Miasto  Miejsce           Zawodnik Country_abbrev  Punkty  \
# 0  2023-11-25   Ruka        1       KRAFT Stefan            AUT     100
# 1  2023-11-25   Ruka        2       PASCHKE Pius            DEU      80
# 2  2023-11-25   Ruka        3      LEYHE Stephan            DEU      60
# 3  2023-11-25   Ruka        4  WELLINGER Andreas            DEU      50
# 4  2023-11-25   Ruka        5  TSCHOFENIG Daniel            AUT      45
#
#    Strata
# 0       0
# 1     -20
# 2     -40
# 3     -50
# 4     -55

# %%
df_wc_results_cum.loc[df_wc_results_cum["Country_abbrev"].isna()]
# Out:
#          WC_Date                  Miasto  Miejsce            Zawodnik  \
# 29    2023-11-25                    Ruka       30  ZOGRAFSKI Vladimir
# 51    2023-11-26                    Ruka       22  ZOGRAFSKI Vladimir
# 86    2023-12-02             Lillehammer       19  ZOGRAFSKI Vladimir
# 130   2023-12-03             Lillehammer       18  ZOGRAFSKI Vladimir
# 180   2023-12-09             Klingenthal       22  ZOGRAFSKI Vladimir
# 229   2023-12-10             Klingenthal       24  ZOGRAFSKI Vladimir
# 274   2023-12-16               Engelberg       22  ZOGRAFSKI Vladimir
# 325   2023-12-17               Engelberg       25  ZOGRAFSKI Vladimir
# 374   2023-12-29              Oberstdorf       26  ZOGRAFSKI Vladimir
# 424   2024-01-01  Garmisch-Partenkirchen       27  ZOGRAFSKI Vladimir
# 478   2024-01-03               Innsbruck       29  ZOGRAFSKI Vladimir
# 532   2024-01-06           Bischofshofen       30  ZOGRAFSKI Vladimir
# ...

# %%
df_wc_results_cum.loc[df_wc_results_cum["Zawodnik"] == 'ZOGRAFSKI Vladimir','Country_abbrev']= df_wc_results_cum.loc[df_wc_results_cum["Zawodnik"] == 'ZOGRAFSKI Vladimir','Country_abbrev'].fillna('BUL')
df_wc_results_cum.loc[df_wc_results_cum["Zawodnik"] == 'MARUSIAK Yevhen','Country_abbrev'] = df_wc_results_cum.loc[df_wc_results_cum["Zawodnik"] == 'MARUSIAK Yevhen','Country_abbrev'].fillna('UKR')

# %%
df_wc_results_cum["Zawodnik"] = df_wc_results_cum["Zawodnik"].str.replace('ZOGRAFSKI Vladimir','ZOGRAFSKI Władimir').str.replace('MARUSIAK Yevhen','MARUSIAK Jewhen')

# %%
df_wc_results_cum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1820 entries, 0 to 1819
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   WC_Date         1820 non-null   object
#  1   Miasto          1820 non-null   object
#  2   Miejsce         1820 non-null   int32
#  3   Zawodnik        1820 non-null   object
#  4   Country_abbrev  1820 non-null   object
#  5   Punkty          1820 non-null   int32
#  6   Strata          1820 non-null   int32
# dtypes: int32(3), object(4)
# memory usage: 92.4+ KB

# %%
# insert data to sql table
from sqlalchemy import create_engine, text
import pandas as pd

# Database connection parameters
server_name = 'DESKTOP-F00PL4B\\SQLEXPRESS01'  # Double backslash to escape
database_name = 'PortfolioProject'
standings_table_name = 'WC_StandingsCum2324'
calendar_table_name = 'WC_Calendar2324'
overall_table_name = 'WC_Standings2324'

# SQLAlchemy engine creation with Windows Authentication
engine = create_engine(f"mssql+pyodbc://@{server_name}/{database_name}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# Step 1: Retrieve WC_IDs from WC_Calendar2324 based on WC_Date and Miasto
with engine.connect() as connection:
    calendar_query = text(f"SELECT ID, WC_Date, Miasto FROM {calendar_table_name}")
    overall_query = text(f'SELECT Standing_ID, Athlete FROM {overall_table_name}')
    calendar_df = pd.read_sql(calendar_query, connection)
    overall_df = pd.read_sql(overall_query,connection)
    calendar_df["WC_Date"] = calendar_df["WC_Date"].astype('str')

# Step 2: Merge WC_IDs with df_wc_results
# Assuming df_wc_results has columns "WC_Date" and "Miasto" for matching
df_wc_results_cum_to_sql = df_wc_results_cum.merge(calendar_df, on=["WC_Date","Miasto"], how="left")
df_wc_results_cum_to_sql = df_wc_results_cum_to_sql.merge(overall_df,left_on='Zawodnik',right_on='Athlete', how="left")

# Step 3: Ensure we only keep the relevant columns
df_wc_results_cum_to_sql = df_wc_results_cum_to_sql.rename(columns={'ID':'WC_ID'})
df_wc_results_cum_to_sql = df_wc_results_cum_to_sql.loc[:,
                                                ["WC_ID","Standing_ID","Miejsce","Zawodnik","Country_abbrev",
                                                 "Punkty","Strata"]]

# Step 4: Truncate the results table before inserting new data
with engine.connect() as connection:
    with connection.begin() as transaction:
        connection.execute(text(f"DELETE FROM {standings_table_name}"))
        connection.execute(text(f"DBCC CHECKIDENT ('{standings_table_name}', RESEED,0)"))
        transaction.commit()

# Insert DataFrame into the existing table with column mapping
df_wc_results_cum_to_sql.to_sql(name=standings_table_name, con=engine, if_exists='append', index=False)

# Close the database connection
engine.dispose()

# %%
df_wc_results = df_wc_results.merge(df_wc_standings[["Athlete","Country_abbrev"]],how="left",left_on="Zawodnik", right_on="Athlete")
df_wc_results.drop(columns={"Kraj","Athlete"},inplace=True)
df_wc_results.rename(columns={"Country_abbrev":"Kraj"},inplace=True)
df_wc_results = df_wc_results.loc[:,["WC_Date","Miasto","Miejsce","Zawodnik","Kraj","Skok_1","Skok_2","Skok_3","Nota"]]

# %%
df_wc_results
# Out:
#          WC_Date   Miasto  Miejsce           Zawodnik Kraj  Skok_1  Skok_2  \
# 0     2023-11-25     Ruka      1.0       KRAFT Stefan  AUT   144.0   143.0
# 1     2023-11-25     Ruka      2.0       PASCHKE Pius  DEU   142.0   142.5
# 2     2023-11-25     Ruka      3.0      LEYHE Stephan  DEU   137.0   143.5
# 3     2023-11-25     Ruka      4.0  WELLINGER Andreas  DEU   142.0   136.0
# 4     2023-11-25     Ruka      5.0  TSCHOFENIG Daniel  AUT   136.0   140.5
# ...          ...      ...      ...                ...  ...     ...     ...
# 1517  2024-03-24  Planica     26.0      KYTOSAHO Niko  FIN   213.0   199.5
# 1518  2024-03-24  Planica     27.0      LEYHE Stephan  DEU   199.0   200.5
# 1519  2024-03-24  Planica     28.0        AALTO Antti  FIN   193.0   186.5
# 1520  2024-03-24  Planica     29.0      KUBACKI Dawid  POL   194.0   187.5
# 1521  2024-03-24  Planica      NaN          HOERL Jan  AUT     NaN     NaN
#
#       Skok_3   Nota
# 0        NaN  326.2
# 1        NaN  315.6
# ...

# %%
df_wc_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1522 entries, 0 to 1521
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   WC_Date   1522 non-null   object
#  1   Miasto    1522 non-null   object
#  2   Miejsce   1494 non-null   float64
#  3   Zawodnik  1522 non-null   object
#  4   Kraj      1427 non-null   object
#  5   Skok_1    1516 non-null   float64
#  6   Skok_2    914 non-null    float64
#  7   Skok_3    10 non-null     float64
#  8   Nota      1516 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 118.9+ KB

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Database connection parameters
server_name = 'DESKTOP-F00PL4B\\SQLEXPRESS01'  # Double backslash to escape
database_name = 'PortfolioProject'
results_table_name = 'WC_Results2324'
calendar_table_name = 'WC_Calendar2324'
overall_table_name = 'WC_Standings2324'

# SQLAlchemy engine creation with Windows Authentication
engine = create_engine(f"mssql+pyodbc://@{server_name}/{database_name}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# Step 1: Retrieve WC_IDs from WC_Calendar2324 based on WC_Date and Miasto
with engine.connect() as connection:
    calendar_query = text(f"SELECT ID, WC_Date, Miasto FROM {calendar_table_name}")
    overall_query = text(f'SELECT Standing_ID, Athlete FROM {overall_table_name}')
    calendar_df = pd.read_sql(calendar_query, connection)
    overall_df = pd.read_sql(overall_query,connection)
    calendar_df["WC_Date"] = calendar_df["WC_Date"].astype('str')


# Step 2: Merge WC_IDs with df_wc_results
# Assuming df_wc_results has columns "WC_Date" and "Miasto" for matching
df_wc_results_to_sql = df_wc_results.merge(calendar_df, on=["WC_Date","Miasto"], how="left")
df_wc_results_to_sql = df_wc_results_to_sql.merge(overall_df,left_on='Zawodnik',right_on='Athlete', how="left")

# Step 3: Ensure we only keep the relevant columns
df_wc_results_to_sql = df_wc_results_to_sql.rename(columns={'ID':'WC_ID'})
df_wc_results_to_sql = df_wc_results_to_sql.loc[:,
                                                ["WC_ID","Standing_ID","Miasto","Miejsce","Zawodnik","Kraj",
                                                 "Skok_1","Skok_2","Skok_3","Nota"]]

# Step 4: Truncate the results table before inserting new data
with engine.connect() as connection:
    with connection.begin() as transaction:
        connection.execute(text(f"DELETE FROM {results_table_name}"))
        connection.execute(text(f"DBCC CHECKIDENT ('{results_table_name}', RESEED,0)"))
        transaction.commit()

# Insert DataFrame into the existing table with column mapping
df_wc_results_to_sql.to_sql(name=results_table_name, con=engine, if_exists='append', index=False)

# Close the database connection
engine.dispose()
